# %% [markdown]
# # Cloud PC Hybrid Colab
#
# Use this notebook for GPU/RAM-heavy work, AI/LLM, and Kaggle datasets.

# %%
# !apt-get update -y
# !apt-get install -y debootstrap proot curl ca-certificates xz-utils tar git python3-pip procps iproute2 net-tools

# %%
# %pip install -q kaggle
from pathlib import Path

KAGGLE_DIR = Path('/content/.kaggle')
KAGGLE_DIR.mkdir(parents=True, exist_ok=True)
print('Kaggle config dir:', KAGGLE_DIR)
print('Place kaggle.json there if you need dataset access.')

# %%
from pathlib import Path

ROOT = Path('/content/kali-root')
ROOT.mkdir(parents=True, exist_ok=True)
print('ROOT ready:', ROOT)
print('Keep the bootstrap minimal and use Colab for temporary heavy workloads.')
